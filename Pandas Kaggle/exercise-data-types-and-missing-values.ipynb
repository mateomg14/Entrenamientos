# %% [markdown]
# **This notebook is an exercise in the [Pandas](https://www.kaggle.com/learn/pandas) course.  You can reference the tutorial at [this link](https://www.kaggle.com/residentmario/data-types-and-missing-values).**
#
# ---

# %% [markdown]
# # Introduction
#
# Run the following cell to load your data and some utility functions.

# %%
import pandas as pd

reviews = pd.read_csv("winemag-data-130k-v2.csv", index_col=0)

print("Setup complete.")
# Out:
# Setup complete.

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
# Tipo de datos por columna

# %%
# Tipo de dato por columnas 
dtype = reviews.points.dtype

# %% [markdown]
# ## 2.
# Cambiar tipo de datos de una columna especifica

# %%
## cambiar tipo de datos 
point_strings = reviews.points.astype(str)

# %% [markdown]
# ## 3.
# Saber Cuantos Nulos Hay

# %%
len(reviews[reviews.price.isnull()])
# Out:
# 8996

# %%
reviews.price.isnull().sum()
# Out:
# 8996

# %% [markdown]
# ## 4.
# Reemplazar los valores nulos, contarlos por region_1, ordenarlos en forma descendiente

# %%
reviews.region_1.fillna("Unknown").value_counts().sort_values(ascending=False)
# Out:
# Unknown                 21247
# Napa Valley              4480
# Columbia Valley (WA)     4124
# Russian River Valley     3091
# California               2629
#                         ...
# Offida Rosso                1
# Corton Perrières            1
# Isle St. George             1
# Geelong                     1
# Paestum                     1
# Name: region_1, Length: 1230, dtype: int64

# %% [markdown]
# # Keep going
#
# Move on to **[renaming and combining](https://www.kaggle.com/residentmario/renaming-and-combining)**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/pandas/discussion) to chat with other learners.*
